# %% [markdown]
# # Marks Sheet Grading Example for AI, ML and DL

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.DataFrame(np.random.randint(20,32, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df2 = pd.DataFrame(np.random.randint(33,39, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df3 = pd.DataFrame(np.random.randint(40,49, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df4 = pd.DataFrame(np.random.randint(50,59, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df5 = pd.DataFrame(np.random.randint(60,69, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df6 = pd.DataFrame(np.random.randint(70,79, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df7 = pd.DataFrame(np.random.randint(80,100, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])

df = pd.concat([df1,df2,df3,df4,df5,df6,df7])



df.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  27  20  28  23  23
# 1  28  23  21  22  23
# 2  21  27  30  22  23
# 3  24  29  24  20  26
# 4  29  22  27  24  27

# %%
df['obtained'] = df.s1 + df.s2 + df.s3 + df.s4 + df.s5
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained
# 0  27  20  28  23  23       121
# 1  28  23  21  22  23       117
# 2  21  27  30  22  23       123
# 3  24  29  24  20  26       123
# 4  29  22  27  24  27       129

# %%
df['percentage'] = df.obtained / 500 * 100
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained  percentage
# 0  27  20  28  23  23       121        24.2
# 1  28  23  21  22  23       117        23.4
# 2  21  27  30  22  23       123        24.6
# 3  24  29  24  20  26       123        24.6
# 4  29  22  27  24  27       129        25.8

# %% [markdown]
# # apply Symbolic AI, Classicial programming, tranditional programming, Rules Based programmin
# - Rules always define by programmer

# %% [markdown]
# - Rules + Input = Output

# %%
def grade(x):
    if x >= 80:
        return "A+"
    elif x >= 70:
        return "A"
    elif x >= 60:
        return "B"
    elif x >= 50:
        return "C"
    elif x >= 40:
        return "D"
    elif x >= 33:
        return "E"
    else:
        return "F"
    
df['Grade'] = df.percentage.apply(grade)
df.tail()
# Out:
#       s1  s2  s3  s4  s5  obtained  percentage Grade
# 4995  97  98  86  84  90       455        91.0    A+
# 4996  94  99  94  88  97       472        94.4    A+
# 4997  80  88  81  93  90       432        86.4    A+
# 4998  83  94  96  86  87       446        89.2    A+
# 4999  93  96  85  85  93       452        90.4    A+

# %%
df.Grade.value_counts()
# Out:
# B     5000
# D     5000
# C     5000
# A+    5000
# E     5000
# F     5000
# A     5000
# Name: Grade, dtype: int64

# %%
df.corr().plot(kind='bar')

# %%
dic = {
    'F':7,
    "E":6,
    "D":5,
    "C":4,
    "B":3,
    "A":2,
    "A+":1
}
df['Grade1'] = df.Grade.map(dic)
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained  percentage Grade  Grade1
# 0  27  20  28  23  23       121        24.2     F       7
# 1  28  23  21  22  23       117        23.4     F       7
# 2  21  27  30  22  23       123        24.6     F       7
# 3  24  29  24  20  26       123        24.6     F       7
# 4  29  22  27  24  27       129        25.8     F       7

# %%
df.corr().plot(kind='bar')

# %% [markdown]
# # Find Grades(Rules) with Deep Learning
# - input + Output = Rules

# %%
df1 = df[['s1', 's2', 's3', 's4', 's5', 'Grade']]
df1.head(2)
df1 = df1.sample(frac=1)
df1
# Out:
#       s1  s2  s3  s4  s5 Grade
# 3928  43  47  46  48  40     D
# 1314  51  55  54  58  55     C
# 524   76  70  77  70  71     A
# 358   31  31  25  26  31     F
# 4796  36  37  38  36  37     E
# ...   ..  ..  ..  ..  ..   ...
# 3388  98  83  80  99  87    A+
# 920   36  37  33  34  33     E
# 1438  24  25  30  20  25     F
# 1719  61  60  63  63  60     B
# 346   40  41  41  45  48     D
#
# [35000 rows x 6 columns]

# %%
X = df1.loc[:, 's1':'s5']
X.head()
# Out:
#       s1  s2  s3  s4  s5
# 3928  43  47  46  48  40
# 1314  51  55  54  58  55
# 524   76  70  77  70  71
# 358   31  31  25  26  31
# 4796  36  37  38  36  37

# %%
Y = df1[['Grade']]
Y.head()
# Out:
#      Grade
# 3928     D
# 1314     C
# 524      A
# 358      F
# 4796     E

# %% [markdown]
# # Vectorization to Y
# - one-hot-encoding

# %% [raw]
#     A B C
# A   1 0 0
# B   0 1 0
# C   0 0 1

# %%
Y = df1['Grade']
Y = pd.get_dummies(Y)
Y.head()
# Out:
#       A  A+  B  C  D  E  F
# 3928  0   0  0  0  1  0  0
# 1314  0   0  0  1  0  0  0
# 524   1   0  0  0  0  0  0
# 358   0   0  0  0  0  0  1
# 4796  0   0  0  0  0  1  0

# %%
Y.drop_duplicates()
# Out:
#       A  A+  B  C  D  E  F
# 3928  0   0  0  0  1  0  0
# 1314  0   0  0  1  0  0  0
# 524   1   0  0  0  0  0  0
# 358   0   0  0  0  0  0  1
# 4796  0   0  0  0  0  1  0
# 1135  0   0  1  0  0  0  0
# 4434  0   1  0  0  0  0  0

# %% [raw]
#    s1 s2 s3 s4 s5     A   A+  B  C   D   E   F
# [[98,56,79,90,50]] = [.3, .1,.20,.1, .1, .1, .1]

# %% [markdown]
# ##### import some fundamentals lib

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam, SGD

# %% [markdown]
# Create your model network structure
# - first-layer (input_shape = X.no_of_columns)
# - last-layers (output=Y.unique_labels(unique classes))
#     - activation = according to your problems (4.6)
# - Dense(output, )

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(5,)))
model.add(Dense(16, activation='relu', input_shape=(5,)))
model.add(Dense(7, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                192
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 119
# =================================================================
# Total params: 839
# Trainable params: 839
# Non-trainable params: 0
# _________________________________________________________________

# %%
# select loss function based on your problems

model.compile(optimizer=SGD(lr=0.002),
             loss='categorical_crossentropy',
             metrics=['acc'])

# %%
model.fit(X, Y, epochs=30)
# Out:
# Epoch 1/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.9497 - acc: 0.1997
# Epoch 2/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.8834 - acc: 0.2231
# Epoch 3/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.8643 - acc: 0.2383
# Epoch 4/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.8415 - acc: 0.2600
# Epoch 5/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.8184 - acc: 0.2767
# Epoch 6/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.7943 - acc: 0.2919
# Epoch 7/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.7714 - acc: 0.2990
# Epoch 8/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.7487 - acc: 0.3080
# Epoch 9/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.7274 - acc: 0.3108
# Epoch 10/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.7036 - acc: 0.3128
# Epoch 11/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.6561 - acc: 0.3096
# Epoch 12/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.5674 - acc: 0.3323
# Epoch 13/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.4918 - acc: 0.3652
# Epoch 14/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.4261 - acc: 0.4186
# Epoch 15/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.3709 - acc: 0.4636
# Epoch 16/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.3139 - acc: 0.4972
# Epoch 17/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.2625 - acc: 0.5265
# Epoch 18/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.2153 - acc: 0.5490
# Epoch 19/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.1655 - acc: 0.5721
# Epoch 20/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.1205 - acc: 0.5927
# Epoch 21/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.0816 - acc: 0.6124
# Epoch 22/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.0367 - acc: 0.6344
# Epoch 23/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.0015 - acc: 0.6470
# Epoch 24/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.9642 - acc: 0.6608
# Epoch 25/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.9335 - acc: 0.6716
# Epoch 26/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.8931 - acc: 0.6897
# Epoch 27/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.8713 - acc: 0.6933
# Epoch 28/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.8415 - acc: 0.7072
# Epoch 29/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.8156 - acc: 0.7185
# Epoch 30/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.7900 - acc: 0.7319

# %%
df1 = pd.DataFrame(np.random.randint(20,100, size=(20,5)),
                  columns = ['s1','s2','s3','s4','s5'])

df1.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  78  59  44  93  46
# 1  72  40  69  28  22
# 2  68  85  46  67  89
# 3  81  42  92  84  45
# 4  87  44  87  89  27

# %%
Y.columns.take(np.argmax(model.predict([[90,98,95,97,95]]), axis=1))
# Out:
# Index(['A'], dtype='object')

# %%
df1['predict']=Y.columns.take(np.argmax(model.predict(df1.loc[:,'s1':'s5']), axis=1))
df1
# Out:
#     s1  s2  s3  s4  s5 predict
# 0   78  59  44  93  46      A+
# 1   72  40  69  28  22       F
# 2   68  85  46  67  89       F
# 3   81  42  92  84  45       F
# 4   87  44  87  89  27       F
# 5   77  86  87  24  63       F
# 6   62  72  59  83  84       F
# 7   48  92  74  83  38       F
# 8   73  23  54  64  85       F
# 9   37  95  98  42  37       F
# 10  72  96  52  58  87       F
# 11  91  20  40  29  88       F
# 12  50  29  25  31  98       F
# 13  77  46  44  56  58       F
# 14  63  36  53  23  50       F
# 15  56  71  53  34  56       F
# 16  86  81  70  62  34       F
# 17  30  47  55  83  68       F
# 18  31  27  30  61  46       F
# 19  34  87  63  73  42       F

# %% [markdown]
# # Find Grades(Rules) With Machine Learning

# %%
# Load libraries
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
#split dataset in features and target variable
feature_cols = ['percentage']
X = df[feature_cols] # Features
y = df.Grade # Target variable

# %%
X.head(1)
# Out:
#    percentage
# 0        24.2

# %%
y.head(1)
# Out:
# 0    F
# Name: Grade, dtype: object

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# %%
# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

# %%
#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
from sklearn import tree
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(clf, filled=tree, class_names=True,
              fontsize=8)
# Out:
# [Text(651.0, 498.3, 'X[0] <= 79.1\ngini = 0.857\nsamples = 24500\nvalue = [3520, 3543, 3516, 3469, 3505, 3494, 3453]\nclass = y[1]'),
#  Text(558.0, 407.70000000000005, 'X[0] <= 68.9\ngini = 0.833\nsamples = 20957\nvalue = [3520, 0, 3516, 3469, 3505, 3494, 3453]\nclass = y[0]'),
#  Text(465.0, 317.1, 'X[0] <= 59.0\ngini = 0.8\nsamples = 17437\nvalue = [0, 0, 3516, 3469, 3505, 3494, 3453]\nclass = y[2]'),
#  Text(372.0, 226.5, 'X[0] <= 39.1\ngini = 0.75\nsamples = 13921\nvalue = [0, 0, 0, 3469, 3505, 3494, 3453]\nclass = y[4]'),
#  Text(186.0, 135.89999999999998, 'X[0] <= 31.6\ngini = 0.5\nsamples = 6947\nvalue = [0, 0, 0, 0, 0, 3494, 3453]\nclass = y[5]'),
#  Text(93.0, 45.299999999999955, 'gini = 0.0\nsamples = 3453\nvalue = [0, 0, 0, 0, 0, 0, 3453]\nclass = y[6]'),
#  Text(279.0, 45.299999999999955, 'gini = 0.0\nsamples = 3494\nvalue = [0, 0, 0, 0, 0, 3494, 0]\nclass = y[5]'),
#  Text(558.0, 135.89999999999998, 'X[0] <= 49.0\ngini = 0.5\nsamples = 6974\nvalue = [0, 0, 0, 3469, 3505, 0, 0]\nclass = y[4]'),
#  Text(465.0, 45.299999999999955, 'gini = 0.0\nsamples = 3505\nvalue = [0, 0, 0, 0, 3505, 0, 0]\nclass = y[4]'),
#  Text(651.0, 45.299999999999955, 'gini = 0.0\nsamples = 3469\nvalue = [0, 0, 0, 3469, 0, 0, 0]\nclass = y[3]'),
#  Text(558.0, 226.5, 'gini = 0.0\nsamples = 3516\nvalue = [0, 0, 3516, 0, 0, 0, 0]\nclass = y[2]'),
#  Text(651.0, 317.1, 'gini = 0.0\nsamples = 3520\nvalue = [3520, 0, 0, 0, 0, 0, 0]\nclass = y[0]'),
#  Text(744.0, 407.70000000000005, 'gini = 0.0\nsamples = 3543\nvalue = [0, 3543, 0, 0, 0, 0, 0]\nclass = y[1]')]
